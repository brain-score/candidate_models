# %%
% matplotlib inline
% load_ext autoreload
% autoreload 2

import logging
import sys
from matplotlib import pyplot

sys.path.insert(0, '../mkgu/')

logging.basicConfig(stream=sys.stdout, level=logging.getLevelName("DEBUG"))
# Out:
# DEBUG:matplotlib.backends:backend module://ipykernel.pylab.backend_inline version unknown
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Individual models

# %%
from neurality.plot.layerfit import plot

plot('alexnet')
pyplot.savefig('results/layerfit-alexnet.pdf')
# Out:
# DEBUG:neurality.storage._XarrayStorage:Loading from storage: neurality.score_physiology/model=alexnet,model_weights=imagenet,pca_components=1000,neural_data=dicarlo.majaj2015,metric_name=neural_fit
# DEBUG:matplotlib.backends.backend_pdf:Assigning font /b'F1' = '/home/martin/miniconda3/envs/rnn-inference/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# DEBUG:matplotlib.backends.backend_pdf:Embedding font /home/martin/miniconda3/envs/rnn-inference/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# DEBUG:matplotlib.backends.backend_pdf:Writing TrueType font.

# %% [markdown]
# ## Average ordering

# %%
from neurality.plot.layerfit import plot_average_layer_ordering

plot_average_layer_ordering(['alexnet'])
pyplot.savefig('results/layer-ordering.pdf')
# Out:
# Model alexnet
# DEBUG:neurality.storage._XarrayStorage:Loading from storage: neurality.score_physiology/model=alexnet,model_weights=imagenet,pca_components=1000,neural_data=dicarlo.majaj2015,metric_name=neural_fit
# Region IT
# Region V4
# DEBUG:matplotlib.backends.backend_pdf:Assigning font /b'F1' = '/home/martin/miniconda3/envs/rnn-inference/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'
# DEBUG:matplotlib.backends.backend_pdf:Assigning font /b'F2' = '/home/martin/miniconda3/envs/rnn-inference/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf'
# DEBUG:matplotlib.backends.backend_pdf:Embedding font /home/martin/miniconda3/envs/rnn-inference/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf.
# DEBUG:matplotlib.backends.backend_pdf:Writing TrueType font.
# DEBUG:matplotlib.backends.backend_pdf:Embedding font /home/martin/miniconda3/envs/rnn-inference/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf.
# DEBUG:matplotlib.backends.backend_pdf:Writing TrueType font.
