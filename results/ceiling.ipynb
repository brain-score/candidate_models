# %%
# %load_ext autoreload
# %autoreload 2
% matplotlib inline
import sys
from matplotlib import pyplot
sys.path.insert(0, '../mkgu')
from neurality.plot.ceiling import plot

plot()
pyplot.savefig('results/ceiling.train_size.png')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# DEBUG:matplotlib.backends:backend module://ipykernel.pylab.backend_inline version unknown
# DEBUG:neurality.storage._DiskStorage:Loading from storage: neurality.plot.ceiling.compute_ceiling/data=dicarlo.Majaj2015,metric=neural_fit,train_size=0.025
# DEBUG:neurality.storage._DiskStorage:Loading from storage: neurality.plot.ceiling.compute_ceiling/data=dicarlo.Majaj2015,metric=neural_fit,train_size=0.05
# DEBUG:neurality.storage._DiskStorage:Loading from storage: neurality.plot.ceiling.compute_ceiling/data=dicarlo.Majaj2015,metric=neural_fit,train_size=0.1
# DEBUG:neurality.storage._DiskStorage:Loading from storage: neurality.plot.ceiling.compute_ceiling/data=dicarlo.Majaj2015,metric=neural_fit,train_size=0.2
# DEBUG:neurality.storage._DiskStorage:Loading from storage: neurality.plot.ceiling.compute_ceiling/data=dicarlo.Majaj2015,metric=neural_fit,train_size=0.3
# ...
