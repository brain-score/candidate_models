# %%
% load_ext autoreload
% autoreload 2
% matplotlib inline
from matplotlib import pyplot
import sys

sys.path.insert(0, '../mkgu/')
from neurality.plot.pca import plot_model_pcas

plot_model_pcas('alexnet', layer='features.12')
pyplot.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
